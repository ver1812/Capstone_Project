# %% [markdown]
# # File to download All data Locally.

# %%
import os
from datasets import load_dataset
import pandas as pd

RAW_DIR = "raw"
os.makedirs(RAW_DIR, exist_ok=True)

# %% [markdown]
# # Deepset Dataset
